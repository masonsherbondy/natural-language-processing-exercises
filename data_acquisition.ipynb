# %% [markdown]
# # Data Acquisition Exercises

# %% [markdown]
# By the end of this exercise, you should have a file named acquire.py that contains the specified functions. If you wish, you may break your work into separate files for each website (e.g. acquire_codeup_blog.py and acquire_news_articles.py), but the end function should be present in acquire.py (that is, acquire.py should import get_blog_articles from the acquire_codeup_blog module.)

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import mason_functions as mf
import requests

# %% [markdown]
# ### Soup Methods
# * soup.select('.class'): to get all the elements with class class
# * soup.select_one('.class'): to get the first element with class class
# * soup.h2: to get the first h2 element
# * soup.find_all('h2'): to get all the elements with tag name of h2
# * soup('h2') : same as find_all method above
# * soup.find('h2'): finds the first matching element

# %% [markdown]
# ## Exercise I Codeup Blog Articles
#
# Visit Codeup's Blog and record the urls for at least 5 distinct blog posts. For each post, you should scrape at least the post's title and content.
#
# Encapsulate your work in a function named get_blog_articles that will return a list of dictionaries, with each dictionary representing one article. The shape of each dictionary should look like this:
#
#
# {
#     'title': 'the title of the article',
#     'content': 'the full text content of the article'
# }
#
# Plus any additional properties you think might be helpful.
#
# #### Bonus: Scrape the text of all the articles linked on codeup's blog page.

# %%
# define url to scrape
url = 'https://codeup.com/blog/'

# define headers
headers = {'User-Agent': 'Codeup Data Server'}

# get a response from the server
response = requests.get(url, headers = headers)

# assign variable to text requested
html = response.text

# view html text
# html

# %%
# convert html into a good soup
soup = BeautifulSoup(html)

# print beautiful soup
# print(soup.prettify())

# %%
# what's here?
h2s = soup.find('h2').text
h2s
# Out:
# 'VET TEC Funding Now Available For Dallas Veterans'

# %%
# select .entry-title elements
entry_titles = soup.select('.entry-title')
entry_titles
# Out:
# [<h2 class="entry-title"><a href="https://codeup.com/codeup-news/codeup-start-dates-for-march-2022/">Codeup Start Dates for March 2022</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/codeup-news/vet-tec-funding-dallas/">VET TEC Funding Now Available For Dallas Veterans</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/codeup-news/dallas-campus-re-opens-with-new-grant-partner/">Dallas Campus Re-opens With New Grant Partner</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/dallas-newsletter/codeup-dallas-open-house/">Codeup Dallas Open House</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/codeup-news/codeups-placement-team-continues-setting-records/">Codeup’s Placement Team Continues Setting Records</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/it-training/it-certifications-101/">IT Certifications 101: Why They Matter, and Why They Don’t</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/cybersecurity/a-rise-in-cyber-attacks-means-opportunities-for-veterans-in-san-antonio/">A rise in cyber attacks means opportunities for veterans in San Antonio</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/codeup-news/use-your-gi-bill-benefits-to-land-a-job-in-tech/">Use your GI Bill® benefits to Land a Job in Tech</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/tips-for-prospective-students/which-program-is-right-for-me-cyber-security-or-systems-engineering/">Which program is right for me: Cyber Security or Systems Engineering?</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/it-training/what-the-heck-is-system-engineering/">What the Heck is System Engineering?</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/alumni-stories/from-speech-pathology-to-business-intelligence/">From Speech Pathology to Business Intelligence</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/behind-the-billboards/boris-behind-the-billboards/">Boris – Behind the Billboards</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/codeup-news/is-codeup-the-best-bootcamp-in-san-antonio-or-the-world/">Is Codeup the Best Bootcamp in San Antonio…or the World?</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/codeup-news/codeup-launches-first-podcast-hire-tech/">Codeup Launches First Podcast: Hire Tech</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/tips-for-prospective-students/why-should-i-become-a-system-administrator/">Why Should I Become a System Administrator?</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/codeup-news/codeup-candidate-for-accreditation/">Announcing our Candidacy for Accreditation!</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/codeup-news/codeup-takes-over-more-of-the-historic-vogue-building/">Codeup Takes Over More of the Historic Vogue Building</a></h2>,
#  <h2 class="entry-title"><a href="https://codeup.com/codeup-news/inclusion-at-codeup-during-pride-month-and-always/">Inclusion at Codeup During Pride Month (and Always)</a></h2>]

# %%
# get string for title
soup.title.string
# Out:
# 'Blog - Codeup'

# %%
# understand links
link = entry_titles[0].a['href']
link
# Out:
# 'https://codeup.com/codeup-news/codeup-start-dates-for-march-2022/'

# %%
# understand titles
title = entry_titles[0].a.text
title
# Out:
# 'Codeup Start Dates for March 2022'

# %%
# try first link
url = entry_titles[0].a['href']

# get response with requests library
response = requests.get(url, headers = headers)

# get html
html = response.text

# make good soup
soup = BeautifulSoup(html)

# beautiful soup
# print(soup.prettify())

# %%
# get entry content
corpus = soup.select('.entry-content')
corpus
# Out:
# [<div class="entry-content">
#  <p>As we approach the end of January we wanted to look forward to our next start dates for all of our current programs.</p>
#  <h3>Full Stack Web Development – 3/7/22</h3>
#  <p>Full Stack Web Development is the first program we built and also our most popular. You’ve asked and we listened! Our next Web Development cohort will start on 3/7/2022 and is ENTIRELY VIRTUAL! THESE SEATS WILL GO FAST!</p>
#  <p>As one of the most in-demand jobs in the country, software and web development is the tech career with the newest jobs. In the U.S., there’s:</p>
#  <ul>
#  <li>1.5 million developer jobs*</li>
#  <li>250,000 of them remain open</li>
#  <li>a high growth rate of 13%*</li>
#  </ul>
#  <p> </p>
#  <h3>Data Science – 3/22/22</h3>
#  <p>Our first new Data Science class of 2022 starts Monday 3/22/2022 at our downtown campus at the Vogue building.</p>
#  <p>Why consider pivoting careers to Data Science?</p>
#  <ul>
#  <li>#1 job in America from 2016-2020 (Glassdoor*)</li>
#  <li>650% increase in data science positions since 2012</li>
#  <li>Nearly 12 million new jobs between 2019 and 2029</li>
#  <li>31% ten-year growth rate</li>
#  </ul>
#  <p>The supply of data scientists remains painfully low compared to the outrageous demand. YOU can help close the gap while launching a fulfilling, secure, and high-paying career – one of the very best in the country!</p>
#  <p>Employers are scrambling to find talent due to a lack of qualified applicants. YOU can help fill the gap while future-proofing your skillset. Have the flexibility, security, and salary that you’ve always wanted in a career.</p>
#  <p>Are you ready to launch your career in tech? Apply today so our admissions team can save your seat and get your name on the list. Our <a href="https://codeup.com/apply-now/">application can be found here. </a></p>
#  <p>Want to experience Codeup early? Join one of our workshops to get an intro to a specific coding language, learn about our financing options, or maybe even code yourself a resume! <a href="https://codeup.com/events/">All of our events can be located here. </a></p>
#  <p>We can’t wait to help you launch your career in tech!</p>
#  </div>]

# %%
# get content
content = corpus[0].text.strip()
content
# Out:
# 'As we approach the end of January we wanted to look forward to our next start dates for all of our current programs.\nFull Stack Web Development – 3/7/22\nFull Stack Web Development is the first program we built and also our most popular. You’ve asked and we listened! Our next Web Development cohort will start on 3/7/2022 and is ENTIRELY VIRTUAL! THESE SEATS WILL GO FAST!\nAs one of the most in-demand jobs in the country, software and web development is the tech career with the newest jobs. In the U.S., there’s:\n\n1.5 million developer jobs*\n250,000 of them remain open\na high growth rate of 13%*\n\n\xa0\nData Science – 3/22/22\nOur first new Data Science class of 2022 starts Monday 3/22/2022 at our downtown campus at the Vogue building.\nWhy consider pivoting careers to Data Science?\n\n#1 job in America from 2016-2020 (Glassdoor*)\n650% increase in data science positions since 2012\nNearly 12 million new jobs between 2019 and 2029\n31% ten-year growth rate\n\nThe supply of data scientists remains painfully low compared to the outrageous demand. YOU can help close the gap while launching a fulfilling, secure, and high-paying career – one of the very best in the country!\nEmployers are scrambling to find talent due to a lack of qualified applicants. YOU can help fill the gap while future-proofing your skillset. Have the flexibility, security, and salary that you’ve always wanted in a career.\nAre you ready to launch your career in tech? Apply today so our admissions team can save your seat and get your name on the list. Our application can be found here.\xa0\nWant to experience Codeup early? Join one of our workshops to get an intro to a specific coding language, learn about our financing options, or maybe even code yourself a resume! All of our events can be located here.\xa0\nWe can’t wait to help you launch your career in tech!'

# %%
# get publish date
publish_date = soup.select('.published')
publish_date
# Out:
# [<span class="published">Jan 26, 2022</span>]

# %%
# get date
date = publish_date[0].text
date
# Out:
# 'Jan 26, 2022'

# %%
def get_blog_articles():
    
    '''
    This function acquires the blog articles from the Codeup Blog
    '''
    
    url = 'https://codeup.com/blog/'    # define url to scrape
    headers = {'User-Agent': 'Codeup Data Server'}    # define headers
    response = requests.get(url, headers = headers)    # get a response from the server
    html = response.text    # assign variable to text requested
    soup = BeautifulSoup(html)    # convert html into a good soup
    
    entry_titles = soup.select('.entry-title')    # select .entry-title elements
    output = []    # set an empty list
    
    for n in range(len(entry_titles)):    # commence loop to run through list of .entry-title elements
        link = entry_titles[n].a['href']    # get link
        title = entry_titles[n].a.text    # get title
        response = requests.get(link, headers = headers)    # get response with requests library
        html = response.text    # get html
        soup = BeautifulSoup(html)    # water the soup
        corpus = soup.select('.entry-content')    # get the corpus
        content = corpus[0].text.strip()    # get the content of the corpus
        publish_date = soup.select('.published')    # get publish date
        date = publish_date[0].text    # get date
    
        article_info = {               # create dictionary
            'publish_date': date,
            'article': title,
            'content': content,
            'link': link
        }
        
        output.append(article_info)    # add dictionary to the list
        
    blogs = pd.DataFrame(output)    # create dataframe from accumulated info
    
    return blogs

# %%
blogs = get_blog_articles()
blogs
# Out:
#     publish_date                                            article  \
# 0   Jan 26, 2022                  Codeup Start Dates for March 2022
# 1    Jan 7, 2022  VET TEC Funding Now Available For Dallas Veterans
# 2   Dec 30, 2021      Dallas Campus Re-opens With New Grant Partner
# 3   Nov 30, 2021                           Codeup Dallas Open House
# 4   Nov 19, 2021  Codeup’s Placement Team Continues Setting Records
# 5   Nov 18, 2021  IT Certifications 101: Why They Matter, and Wh...
# 6   Nov 17, 2021  A rise in cyber attacks means opportunities fo...
# 7    Nov 4, 2021   Use your GI Bill® benefits to Land a Job in Tech
# 8   Oct 28, 2021  Which program is right for me: Cyber Security ...
# 9   Oct 21, 2021               What the Heck is System Engineering?
# 10  Oct 18, 2021     From Speech Pathology to Business Intelligence
# 11   Oct 3, 2021                      Boris – Behind the Billboards
# 12  Sep 16, 2021  Is Codeup the Best Bootcamp in San Antonio…or ...
# 13  Aug 25, 2021           Codeup Launches First Podcast: Hire Tech
# 14  Aug 23, 2021        Why Should I Become a System Administrator?
# 15  Jun 30, 2021        Announcing our Candidacy for Accreditation!
# 16  Jun 21, 2021  Codeup Takes Over More of the Historic Vogue B...
# 17   Jun 4, 2021  Inclusion at Codeup During Pride Month (and Al...
#
#                                               content  \
# 0   As we approach the end of January we wanted to...
# 1   We are so happy to announce that VET TEC benef...
# 2   We are happy to announce that our Dallas campu...
# 3   Come join us for the re-opening of our Dallas ...
# 4   Our Placement Team is simply defined as a grou...
# 5   AWS, Google, Azure, Red Hat, CompTIA…these are...
# 6   In the last few months, the US has experienced...
# 7   As the end of military service gets closer, ma...
# 8   What IT Career should I choose?\nIf you’re thi...
# 9   Codeup offers a 13-week training program: Syst...
# 10  By: Alicia Gonzalez\nBefore Codeup, I was a ho...
# 11
# 12  Looking for the best data science bootcamp in ...
# 13  Any podcast enthusiasts out there? We are plea...
# 14  With so many tech careers in demand, why choos...
# 15  Did you know that even though we’re an indepen...
# 16  Codeup is moving into another floor of our His...
# 17  Happy Pride Month! Pride Month is a dedicated ...
#
#                                                  link
# 0   https://codeup.com/codeup-news/codeup-start-da...
# 1   https://codeup.com/codeup-news/vet-tec-funding...
# 2   https://codeup.com/codeup-news/dallas-campus-r...
# 3   https://codeup.com/dallas-newsletter/codeup-da...
# 4   https://codeup.com/codeup-news/codeups-placeme...
# 5   https://codeup.com/it-training/it-certificatio...
# 6   https://codeup.com/cybersecurity/a-rise-in-cyb...
# 7   https://codeup.com/codeup-news/use-your-gi-bil...
# 8   https://codeup.com/tips-for-prospective-studen...
# 9   https://codeup.com/it-training/what-the-heck-i...
# 10  https://codeup.com/alumni-stories/from-speech-...
# 11  https://codeup.com/behind-the-billboards/boris...
# 12  https://codeup.com/codeup-news/is-codeup-the-b...
# 13  https://codeup.com/codeup-news/codeup-launches...
# 14  https://codeup.com/tips-for-prospective-studen...
# 15  https://codeup.com/codeup-news/codeup-candidat...
# 16  https://codeup.com/codeup-news/codeup-takes-ov...
# 17  https://codeup.com/codeup-news/inclusion-at-co...

# %%
# view content from 'Codeup Start Dates for March 22' or the [0] indice
blogs.content[0]
# Out:
# 'As we approach the end of January we wanted to look forward to our next start dates for all of our current programs.\nFull Stack Web Development – 3/7/22\nFull Stack Web Development is the first program we built and also our most popular. You’ve asked and we listened! Our next Web Development cohort will start on 3/7/2022 and is ENTIRELY VIRTUAL! THESE SEATS WILL GO FAST!\nAs one of the most in-demand jobs in the country, software and web development is the tech career with the newest jobs. In the U.S., there’s:\n\n1.5 million developer jobs*\n250,000 of them remain open\na high growth rate of 13%*\n\n\xa0\nData Science – 3/22/22\nOur first new Data Science class of 2022 starts Monday 3/22/2022 at our downtown campus at the Vogue building.\nWhy consider pivoting careers to Data Science?\n\n#1 job in America from 2016-2020 (Glassdoor*)\n650% increase in data science positions since 2012\nNearly 12 million new jobs between 2019 and 2029\n31% ten-year growth rate\n\nThe supply of data scientists remains painfully low compared to the outrageous demand. YOU can help close the gap while launching a fulfilling, secure, and high-paying career – one of the very best in the country!\nEmployers are scrambling to find talent due to a lack of qualified applicants. YOU can help fill the gap while future-proofing your skillset. Have the flexibility, security, and salary that you’ve always wanted in a career.\nAre you ready to launch your career in tech? Apply today so our admissions team can save your seat and get your name on the list. Our application can be found here.\xa0\nWant to experience Codeup early? Join one of our workshops to get an intro to a specific coding language, learn about our financing options, or maybe even code yourself a resume! All of our events can be located here.\xa0\nWe can’t wait to help you launch your career in tech!'

# %%
# import time

# # Save the blogs as json:
# today = time.strftime('%Y-%m-%d')
# blogs.to_json(f'codeup_blog_{today}.json')

# %% [markdown]
# ## Exercise II News Articles
#
# We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# Write a function that scrapes the news articles for the following topics:
#
# * Business
# * Sports
# * Technology
# * Entertainment
#
# The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:
#
#
# {
#     'title': 'The article title',
#     'content': 'The article content',
#     'category': 'business' # for example
# }
#
# Hints:
#
# a. Start by inspecting the website in your browser. Figure out which elements will be useful.
#
# b. Start by creating a function that handles a single article and produces a dictionary like the one above.
#
# c. Next create a function that will find all the articles on a single page and call the function you created in the last step for every article on the page.
#
# d. Now create a function that will use the previous two functions to scrape the articles from all the pages that you need, and do any additional processing that needs to be done.

# %%
url = 'https://inshorts.com/en/read/business'    # define url
headers = {'User-Agent': 'Codeup Data Server'}     # define headers
response = requests.get(url, headers = headers)    # get a response from the server
html = response.text    # assign variable to text requested
soup = BeautifulSoup(html)    # convert html into a good soup
# print(soup.prettify())    # beautiful soup

# %%
cards = soup.select('.news-card')
cards[0]
# Out:
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/rbi-cancels-licence-of-mahabased-independence-cooperative-bank-1643895020128" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Shalini Ojha" itemprop="name"></span>
# </span>
# <span content="RBI cancels licence of Maha-based Independence Co-operative Bank" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/02_feb/3_thu/img_1643894076621_61.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/02_feb/3_thu/img_1643894076621_61.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/rbi-cancels-licence-of-mahabased-independence-cooperative-bank-1643895020128" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'RBI%20cancels%20licence%20of%20Maha-based%20Independence%20Co-operative%20Bank)' });" style="color:#44444d!important">
# <span itemprop="headline">RBI cancels licence of Maha-based Independence Co-operative Bank</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/rbi-cancels-licence-of-mahabased-independence-cooperative-bank-1643895020128"><span class="short">short</span></a> by <span class="author">Shalini Ojha</span> /
#       <span class="time" content="2022-02-03T13:30:20.000Z" itemprop="datePublished">07:00 pm</span> on <span clas="date">03 Feb 2022,Thursday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">RBI has cancelled licence of Maharashtra-based Independence Co-operative Bank, citing inadequate capital. It will cease to carry on banking operations from the close of business on February 3. In the present situation, the bank won't be able to pay its depositors in full, RBI said. It added that the bank didn't comply with multiple sections of Banking Regulation Act, 1949. </div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/rbi-cancels-licence-of-mahabased-independence-cooperative-bank-1643895020128"><span class="short">short</span></a> by <span class="author">Shalini Ojha</span> /
#       <span class="time" content="2022-02-03T13:30:20.000Z" itemprop="dateModified">07:00 pm</span> on <span class="date">03 Feb</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.moneycontrol.com/news/business/rbi-cancels-licence-of-maharashtra-based-independence-co-operative-bank-8034241.html/amp?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'Moneycontrol' });" target="_blank">Moneycontrol</a></div>
# </div>
# </div>

# %%
# headline
headline = cards[0].find('span', itemprop = 'headline').text
headline
# Out:
# 'RBI cancels licence of Maha-based Independence Co-operative Bank'

# %%
# corpus
corpus = cards[0].find('div', itemprop = 'articleBody').text
corpus
# Out:
# "RBI has cancelled licence of Maharashtra-based Independence Co-operative Bank, citing inadequate capital. It will cease to carry on banking operations from the close of business on February 3. In the present situation, the bank won't be able to pay its depositors in full, RBI said. It added that the bank didn't comply with multiple sections of Banking Regulation Act, 1949. "

# %%
# publish date
date = cards[0].find('span', clas = 'date').text
date
# Out:
# '03 Feb 2022,Thursday'

# %%
# author
author = cards[0].find('span', class_ = 'author').text
author
# Out:
# 'Shalini Ojha'

# %%
# source link
source = cards[0].find('a', class_ = 'source')['href'].strip()
source
# Out:
# 'https://www.moneycontrol.com/news/business/rbi-cancels-licence-of-maharashtra-based-independence-co-operative-bank-8034241.html/amp?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts'

# %%
def get_news_articles(category):
    
    '''
    This function acquires the news articles from the inshorts website for a specificied category of news
    '''
    
    url = f'https://inshorts.com/en/read/{category}'    # define url
    headers = {'User-Agent': 'Codeup Data Server'}     # define headers
    response = requests.get(url, headers = headers)    # get a response from the server
    html = response.text    # assign variable to text requested
    soup = BeautifulSoup(html)    # convert html
    
    output = []    # set an empty list to fill with dictionaries
    
    cards = soup.select('.news-card')    # select all news-cards
    
    # commence loop
    for n in range(len(cards)):
        headline = cards[n].find('span', itemprop = 'headline').text    # get headline
        corpus = cards[n].find('div', itemprop = 'articleBody').text    # get corpus
        date = cards[n].find('span', clas = 'date').text    # get date
        author = cards[n].find('span', class_ = 'author').text    # get author
        source = cards[n].find('a', class_ = 'source')['href'].strip()    # get source link
    
        article_info = {'publish_date': date,    # create dictionary from gathered values
                        'article': headline,
                        'content': corpus,
                        'author': author,
                        'source': source
                       }
        
        output.append(article_info)    # add dictionaries to list
    
    inshorts = pd.DataFrame(output)    # plug dataframe
    
    return inshorts


def get_news(category):
    
    '''
    This function acquires the news articles from the inshorts website for a specificied category of news
    '''
    
    url = f'https://inshorts.com/en/read/{category}'    # define url
    headers = {'User-Agent': 'Codeup Data Server'}     # define headers
    response = requests.get(url, headers = headers)    # get a response from the server
    html = response.text    # assign variable to text requested
    soup = BeautifulSoup(html)    # convert html
    
    output = []    # set an empty list to fill with dictionaries
    
    cards = soup.select('.news-card')    # select all news-cards
    
    # commence loop
    for n in range(len(cards)):
        headline = cards[n].find('span', itemprop = 'headline').text    # get headline
        corpus = cards[n].find('div', itemprop = 'articleBody').text    # get corpus
        date = cards[n].find('span', clas = 'date').text    # get date
        author = cards[n].find('span', class_ = 'author').text    # get author
    
        article_info = {'category': category,
                        'publish_date': date,    # create dictionary from gathered values
                        'article': headline,
                        'content': corpus,
                        'author': author,
                       }
        
        output.append(article_info)    # add dictionaries to list
    
    inshorts = pd.DataFrame(output)    # plug dataframe
    
    return inshorts

# %%
business = get_news_articles('business')
business
# Out:
#             publish_date                                            article  \
# 0   03 Feb 2022,Thursday  RBI cancels licence of Maha-based Independence...
# 1     04 Feb 2022,Friday  This is an infrastructure and growth-focused B...
# 2     04 Feb 2022,Friday  Self-taught beautician to micro-entrepreneur, ...
# 3   03 Feb 2022,Thursday  Facebook parent Meta's $230-billion wipeout bi...
# 4   03 Feb 2022,Thursday  Why did Facebook's parent company Meta lose $2...
# 5     04 Feb 2022,Friday  Ambani, Adani become richer than Zuckerberg af...
# 6   03 Feb 2022,Thursday  Mark Zuckerberg loses $31 bn in one of the big...
# 7     04 Feb 2022,Friday  Facebook facing unprecedented level of competi...
# 8     04 Feb 2022,Friday  Facebook parent Meta's rating cut by JPMorgan ...
# 9     04 Feb 2022,Friday  If board thinks I shouldn't be MD, they can gi...
# 10    04 Feb 2022,Friday  Ashneer Grover seeks removal of CEO Suhail Sam...
# 11    04 Feb 2022,Friday  ₹4,355-cr PMC Bank scam accused arrested in Bi...
# 12  03 Feb 2022,Thursday  Crypto transactions done before April 2022 won...
# 13    04 Feb 2022,Friday  Rakesh Jhunjhunwala-backed Akasa Air to offer ...
# 14  03 Feb 2022,Thursday  Woman banker in UK wins ₹21 cr in case after m...
# 15  03 Feb 2022,Thursday  Emami Founders step down from executive roles ...
# 16  03 Feb 2022,Thursday  Budget will sustain growth, has disappointed m...
# 17    04 Feb 2022,Friday  Nike sues StockX over sale of unauthorised NFT...
# 18    04 Feb 2022,Friday  Before Meta, which firms recorded biggest 1-da...
# 19  03 Feb 2022,Thursday  Musk protected by rights for his tweet on staf...
# 20  03 Feb 2022,Thursday  No property tax for flats with 500 sq ft carpe...
# 21    04 Feb 2022,Friday  Manyavar owner gets ₹945 crore from anchor inv...
# 22  03 Feb 2022,Thursday  MRF to challenge CCI's ₹622 crore cartelisatio...
# 23  03 Feb 2022,Thursday  LIC's embedded value could be set at over ₹5 t...
# 24  03 Feb 2022,Thursday  Banks urge SC to allow Amazon, Reliance to bid...
#
#                                               content             author  \
# 0   RBI has cancelled licence of Maharashtra-based...       Shalini Ojha
# 1   Capex outlay has been increased and private ca...       Roshan Gupta
# 2   The latest episode of Urban Company Impact int...       Roshan Gupta
# 3   Facebook's parent Meta's shares plunged 27% an...     Pragya Swastik
# 4   Facebook parent Meta's shares fell over 20% ea...     Pragya Swastik
# 5   Reliance Industries Chairman Mukesh Ambani and...     Pragya Swastik
# 6   Meta CEO Mark Zuckerberg's wealth dropped by $...     Pragya Swastik
# 7   At a virtual meeting, Meta CEO Mark Zuckerberg...       Kiran Khatri
# 8   JPMorgan Chase analyst Doug Anmuth has downgra...       Kiran Khatri
# 9   When asked whether he considered resigning ami...       Kiran Khatri
# 10  BharatPe Co-founder and MD Ashneer Grover, who...       Kiran Khatri
# 11  Daljit Singh Bal, who was a director of PMC Ba...       Kiran Khatri
# 12  CBDT Chairman JB Mohapatra was quoted by ANI a...     Pragya Swastik
# 13  Billionaire Rakesh Jhunjhunwala-backed Akasa A...       Kiran Khatri
# 14  A woman banker at BNP Paribas in London was aw...     Pragya Swastik
# 15  Emami Founders RS Agarwal and RS Goenka have s...     Pragya Swastik
# 16  Former Infosys CFO TV Mohandas Pai said that t...        Ashley Paul
# 17  Nike sued online reseller StockX in the US for...  Aishwarya Awasthi
# 18  Facebook's parent Meta's shares lost over $251...       Kiran Khatri
# 19  Tesla CEO Elon Musk's lawyers have argued in t...  Aishwarya Awasthi
# 20  Brihanmumbai Municipal Corporation (BMC) on Th...        Ashley Paul
# 21  Ethnic wear brand Manyavar owner Vedant Fashio...     Subhangi Singh
# 22  MRF Ltd said it will challenge Competition Com...        Ashley Paul
# 23  The embedded value of Life Insurance Corporati...        Ashley Paul
# 24  The 27 lenders to Future Group urged the Supre...        Ashley Paul
#
#                                                source
# 0   https://www.moneycontrol.com/news/business/rbi...
# 1   https://www.smallcase.com/smallcase/infra-trac...
# 2                              https://bit.ly/3GuNrVA
# 3   https://www.bloombergquint.com/business/facebo...
# 4   https://www.businessinsider.in/stock-market/ne...
# 5   https://www.moneycontrol.com/news/business/met...
# 6   https://www.bloombergquint.com/business/mark-z...
# 7   https://www.bloombergquint.com/business/zucker...
# 8   https://www.businessinsider.in/stock-market/ne...
# 9   https://www.moneycontrol.com/news/business/sta...
# 10  https://www.bloombergquint.com/business/bharat...
# 11  https://news.abplive.com/business/pmc-bank-sca...
# 12  https://twitter.com/ANI/status/148915535187032...
# 13  https://www.bloombergquint.com/business/billio...
# 14  https://www.bloombergquint.com/onweb/broker-wi...
# 15  https://www.businessinsider.in/business/news/e...
# 16  https://www.moneycontrol.com/news/business/moh...
# 17  https://www.reuters.com/technology/nike-cries-...
# 18  https://www.bloombergquint.com/business/meta-s...
# 19  https://www.bloombergquint.com/onweb/musk-face...
# 20  https://www.moneycontrol.com/news/business/rea...
# 21  https://www.moneycontrol.com/news/business/ipo...
# 22  https://www.moneycontrol.com/news/business/car...
# 23  https://mobile.reuters.com/article/amp/idUKL4N...
# 24  https://www.moneycontrol.com/news/trends/legal...

# %%
url = 'https://inshorts.com/en/read/sports'    # define url
headers = {'User-Agent': 'Codeup Data Server'}     # define headers
response = requests.get(url, headers = headers)    # get a response from the server
html = response.text    # assign variable to text requested
soup = BeautifulSoup(html)    # convert html into a good soup
# print(soup.prettify())    # beautiful soup

# %%
# source link
source = cards[1].find('a', class_ = 'source')['href'].strip()
source
# Out:
# 'https://www.smallcase.com/smallcase/infra-tracker-SCTR_0005?&utm_source=inshorts-budget&utm_medium=dm-branding-iii-nativearticle2&utm_campaign=web-statics-infra'

# %%
get_news_articles('sports')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-84d5680d8bb7> in <module>
# ----> 1 get_news_articles('sports')
#
# <ipython-input-25-bda204395a62> in get_news_articles(category)
#      21         date = cards[n].find('span', clas = 'date').text    # get date
#      22         author = cards[n].find('span', class_ = 'author').text    # get author
# ---> 23         source = cards[n].find('a', class_ = 'source')['href'].strip()    # get source link
#      24
#      25         article_info = {'publish_date': date,    # create dictionary from gathered values
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# test function without source link code
get_news('sports')
# Out:
#    category          publish_date  \
# 0    sports  03 Feb 2022,Thursday
# 1    sports  03 Feb 2022,Thursday
# 2    sports    04 Feb 2022,Friday
# 3    sports  03 Feb 2022,Thursday
# 4    sports  03 Feb 2022,Thursday
# 5    sports  03 Feb 2022,Thursday
# 6    sports    04 Feb 2022,Friday
# 7    sports    04 Feb 2022,Friday
# 8    sports  03 Feb 2022,Thursday
# 9    sports  03 Feb 2022,Thursday
# 10   sports    04 Feb 2022,Friday
# 11   sports    04 Feb 2022,Friday
# 12   sports  03 Feb 2022,Thursday
# 13   sports  03 Feb 2022,Thursday
# 14   sports  03 Feb 2022,Thursday
# 15   sports    04 Feb 2022,Friday
# 16   sports    04 Feb 2022,Friday
# 17   sports  03 Feb 2022,Thursday
# 18   sports    04 Feb 2022,Friday
# 19   sports    04 Feb 2022,Friday
# 20   sports    04 Feb 2022,Friday
# 21   sports    04 Feb 2022,Friday
# 22   sports  03 Feb 2022,Thursday
# 23   sports    04 Feb 2022,Friday
# 24   sports  03 Feb 2022,Thursday
#
#                                               article  \
# 0   I am like a kid who wants to play under MS Dho...
# 1   This auction I am going to just sit back and s...
# 2   Footballer dies after collapsing on pitch due ...
# 3   Dhawan shares pic after testing COVID-19 posit...
# 4   Vettori told me 'Run towards Kohli not batters...
# 5   DD Sports to not live telecast opening, closin...
# 6   Kohli virtually interacts with India U-19 cric...
# 7   Pakistan fast bowler Hasnain's action found il...
# 8   Fan wears jerseys of 7 countries at the same t...
# 9   Sachin congratulates Neeraj Chopra for 2022 La...
# 10  Rashid Khan shares video of his no-look six, s...
# 11  My dream is to play under Dhoni who can help m...
# 12  Federer, Nadal set to team up again at Laver C...
# 13  US beat Honduras 3-0 in -16 °C temperature in ...
# 14  Sadio Mane helps Senegal beat Burkina Faso 3-1...
# 15  Sachin's technique was unbelievable, so much t...
# 16  They need tough love: Vaughan backs Langer to ...
# 17  Medvedev withdraws from Rotterdam Open, Murray...
# 18  Need players who can adapt to different condit...
# 19  Enjoy playing under Rohit who is a really good...
# 20  I am a genuine all-rounder, always had talent ...
# 21  Real Madrid knocked out of Copa del Rey after ...
# 22  India’s Bopanna, Ramkumar reach Tata Open doub...
# 23  All IPL teams will target Shami, Warner won't ...
# 24  Man City, Liverpool or Real Madrid will get Ha...
#
#                                               content           author
# 0   On being asked if he has any preferred team in...     Anmol Sharma
# 1   Mayank Agarwal, who was retained by Punjab Kin...     Anmol Sharma
# 2   A Greek footballer died after collapsing on th...     Ankush Verma
# 3   Team India opener Shikhar Dhawan took to Insta...     Anmol Sharma
# 4   Recalling the time when he joined RCB, Yuzvend...     Anmol Sharma
# 5   Prasar Bharati's CEO Shashi Shekhar Vempati tw...   Pragya Swastik
# 6   Former Team India captain Virat Kohli virtuall...     Anmol Sharma
# 7   Pakistan fast bowler Mohammad Hasnain has been...     Anmol Sharma
# 8   A video went viral showing a fan wearing jerse...     Anmol Sharma
# 9   Sachin Tendulkar took to Twitter to congratula...     Anmol Sharma
# 10  Lahore Qalandars' bowling all-rounder Rashid K...     Anmol Sharma
# 11  Terming the IPL 2021 auction as one which "cha...  Arnab Mukherji
# 12  Laver Cup organisers on Thursday confirmed Rog...      Veer Badani
# 13  The US beat Honduras 3-0 on Wednesday in their...      Veer Badani
# 14  Liverpool’s Sadio Mane on Wednesday scored Sen...      Veer Badani
# 15  Responding to a query on Twitter about his opi...  Arnab Mukherji
# 16  After Chris Silverwood "left" his role as Engl...  Arnab Mukherji
# 17  World number two Daniil Medvedev on Thursday w...      Veer Badani
# 18  Sharing his opinion on the upcoming IPL mega a...  Arnab Mukherji
# 19  Sharing his experience while playing under the...  Arnab Mukherji
# 20  Shardul Thakur said he considers himself as a ...  Arnab Mukherji
# 21  Real Madrid were knocked out of the Copa del R...  Arnab Mukherji
# 22  India’s Rohan Bopanna and Ramkumar Ramanathan ...      Veer Badani
# 23  Sharing his opinion on the IPL mega auction, B...  Arnab Mukherji
# 24  Former Dutch footballer Ruud Gullit said he be...      Veer Badani

# %%
def get_inshorts():
    
    '''
    This function loops through the aforementioned categories and scrapes news article info from these pages
    '''
    
    categories = ['business', 'sports', 'technology', 'entertainment']    # set list of desired categories
    inshorts = pd.DataFrame()    # set empty frame
    for cat in categories:    # commence loop
        df = get_news(cat)    # render dataframe from news article data
        inshorts = pd.concat([inshorts, df])    # concatenate dataframes
    
    return inshorts

# %%
# test function
inshorts = get_inshorts()
inshorts
# Out:
#          category          publish_date  \
# 0        business  03 Feb 2022,Thursday
# 1        business    04 Feb 2022,Friday
# 2        business    04 Feb 2022,Friday
# 3        business  03 Feb 2022,Thursday
# 4        business  03 Feb 2022,Thursday
# ..            ...                   ...
# 19  entertainment    04 Feb 2022,Friday
# 20  entertainment    04 Feb 2022,Friday
# 21  entertainment    04 Feb 2022,Friday
# 22  entertainment    04 Feb 2022,Friday
# 23  entertainment  03 Feb 2022,Thursday
#
#                                               article  \
# 0   RBI cancels licence of Maha-based Independence...
# 1   This is an infrastructure and growth-focused B...
# 2   Self-taught beautician to micro-entrepreneur, ...
# 3   Facebook parent Meta's $230-billion wipeout bi...
# 4   Why did Facebook's parent company Meta lose $2...
# ..                                                ...
# 19  '365 Days' star Michele to make Indian debut w...
# 20  Kangana has been a very supportive & endearing...
# 21  Rejected H'wood projects where Indians weren't...
# 22  Waheeda Rehman stood barefoot in temple set at...
# 23  Priyanka to star opposite Anthony Mackie in ac...
#
#                                               content          author
# 0   RBI has cancelled licence of Maharashtra-based...    Shalini Ojha
# 1   Capex outlay has been increased and private ca...    Roshan Gupta
# 2   The latest episode of Urban Company Impact int...    Roshan Gupta
# 3   Facebook's parent Meta's shares plunged 27% an...  Pragya Swastik
# 4   Facebook parent Meta's shares fell over 20% ea...  Pragya Swastik
# ..                                                ...             ...
# 19  Italian actor Michele Morrone, who starred in ...      Udit Gupta
# 20  Nawazuddin Siddiqui, who has wrapped up Kangan...      Udit Gupta
# 21  Nitu Chandra, who made her Hollywood debut wit...      Udit Gupta
# 22  Rakeysh Omprakash Mehra recalled shooting for ...      Udit Gupta
# 23  Actress Priyanka Chopra will be starring oppos...   Kriti Kambiri
#
# [99 rows x 5 columns]

# %% [markdown]
# ### Bonus: cache the data
#
# Write your code such that the acquired data is saved locally in some form or fashion. Your functions that retrieve the data should prefer to read the local data instead of having to make all the requests everytime the function is called. Include a boolean flag in the functions to allow the data to be acquired "fresh" from the actual sources (re-writing your local cache).

# %%
# inshorts.to_csv('inshorts_nadir.csv')

# %%
# verify data cached appropriately
inshorts = pd.read_csv('inshorts_nadir.csv', index_col = 0)
inshorts
# Out:
#          category          publish_date  \
# 0        business  03 Feb 2022,Thursday
# 1        business    04 Feb 2022,Friday
# 2        business    04 Feb 2022,Friday
# 3        business  03 Feb 2022,Thursday
# 4        business    04 Feb 2022,Friday
# ..            ...                   ...
# 19  entertainment  03 Feb 2022,Thursday
# 20  entertainment    04 Feb 2022,Friday
# 21  entertainment    04 Feb 2022,Friday
# 22  entertainment    04 Feb 2022,Friday
# 23  entertainment    04 Feb 2022,Friday
#
#                                               article  \
# 0   RBI cancels licence of Maha-based Independence...
# 1   This is an infrastructure and growth-focused B...
# 2   Self-taught beautician to micro-entrepreneur, ...
# 3   Facebook parent Meta's $230-billion wipeout bi...
# 4   Facebook facing unprecedented level of competi...
# ..                                                ...
# 19  I don't work thinking I'm so many films old: D...
# 20  Ajay Devgn's first look from Alia-starrer 'Gan...
# 21  Rejected H'wood projects where Indians weren't...
# 22  Emraan shares son's pic on his b'day, says 'Li...
# 23  '365 Days' star Michele to make Indian debut w...
#
#                                               content          author
# 0   RBI has cancelled licence of Maharashtra-based...    Shalini Ojha
# 1   Capex outlay has been increased and private ca...    Roshan Gupta
# 2   The latest episode of Urban Company Impact int...    Roshan Gupta
# 3   Facebook's parent Meta's shares plunged 27% an...  Pragya Swastik
# 4   At a virtual meeting, Meta CEO Mark Zuckerberg...    Kiran Khatri
# ..                                                ...             ...
# 19  Actress Deepika Padukone, who made her Bollywo...   Kriti Kambiri
# 20  Ajay Devgn has shared the first look of his ch...      Udit Gupta
# 21  Nitu Chandra, who made her Hollywood debut wit...      Udit Gupta
# 22  Actor Emraan Hashmi took to Twitter on Thursda...      Udit Gupta
# 23  Italian actor Michele Morrone, who starred in ...      Udit Gupta
#
# [99 rows x 5 columns]

# %%
# verify data cached appropriately
blogs = pd.read_json('codeup_blog_2022-02-04.json')
blogs
# Out:
#     publish_date                                            article  \
# 0   Jan 26, 2022                  Codeup Start Dates for March 2022
# 1    Jan 7, 2022  VET TEC Funding Now Available For Dallas Veterans
# 2   Dec 30, 2021      Dallas Campus Re-opens With New Grant Partner
# 3   Nov 30, 2021                           Codeup Dallas Open House
# 4   Nov 19, 2021  Codeup’s Placement Team Continues Setting Records
# 5   Nov 18, 2021  IT Certifications 101: Why They Matter, and Wh...
# 6   Nov 17, 2021  A rise in cyber attacks means opportunities fo...
# 7    Nov 4, 2021   Use your GI Bill® benefits to Land a Job in Tech
# 8   Oct 28, 2021  Which program is right for me: Cyber Security ...
# 9   Oct 21, 2021               What the Heck is System Engineering?
# 10  Oct 18, 2021     From Speech Pathology to Business Intelligence
# 11   Oct 3, 2021                      Boris – Behind the Billboards
# 12  Sep 16, 2021  Is Codeup the Best Bootcamp in San Antonio…or ...
# 13  Aug 25, 2021           Codeup Launches First Podcast: Hire Tech
# 14  Aug 23, 2021        Why Should I Become a System Administrator?
# 15  Jun 30, 2021        Announcing our Candidacy for Accreditation!
# 16  Jun 21, 2021  Codeup Takes Over More of the Historic Vogue B...
# 17   Jun 4, 2021  Inclusion at Codeup During Pride Month (and Al...
#
#                                               content  \
# 0   As we approach the end of January we wanted to...
# 1   We are so happy to announce that VET TEC benef...
# 2   We are happy to announce that our Dallas campu...
# 3   Come join us for the re-opening of our Dallas ...
# 4   Our Placement Team is simply defined as a grou...
# 5   AWS, Google, Azure, Red Hat, CompTIA…these are...
# 6   In the last few months, the US has experienced...
# 7   As the end of military service gets closer, ma...
# 8   What IT Career should I choose?\nIf you’re thi...
# 9   Codeup offers a 13-week training program: Syst...
# 10  By: Alicia Gonzalez\nBefore Codeup, I was a ho...
# 11
# 12  Looking for the best data science bootcamp in ...
# 13  Any podcast enthusiasts out there? We are plea...
# 14  With so many tech careers in demand, why choos...
# 15  Did you know that even though we’re an indepen...
# 16  Codeup is moving into another floor of our His...
# 17  Happy Pride Month! Pride Month is a dedicated ...
#
#                                                  link
# 0   https://codeup.com/codeup-news/codeup-start-da...
# 1   https://codeup.com/codeup-news/vet-tec-funding...
# 2   https://codeup.com/codeup-news/dallas-campus-r...
# 3   https://codeup.com/dallas-newsletter/codeup-da...
# 4   https://codeup.com/codeup-news/codeups-placeme...
# 5   https://codeup.com/it-training/it-certificatio...
# 6   https://codeup.com/cybersecurity/a-rise-in-cyb...
# 7   https://codeup.com/codeup-news/use-your-gi-bil...
# 8   https://codeup.com/tips-for-prospective-studen...
# 9   https://codeup.com/it-training/what-the-heck-i...
# 10  https://codeup.com/alumni-stories/from-speech-...
# 11  https://codeup.com/behind-the-billboards/boris...
# 12  https://codeup.com/codeup-news/is-codeup-the-b...
# 13  https://codeup.com/codeup-news/codeup-launches...
# 14  https://codeup.com/tips-for-prospective-studen...
# 15  https://codeup.com/codeup-news/codeup-candidat...
# 16  https://codeup.com/codeup-news/codeup-takes-ov...
# 17  https://codeup.com/codeup-news/inclusion-at-co...
